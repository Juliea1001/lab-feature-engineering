# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../learningSet.csv')

# %%
data.shape
# Out:
# (95412, 481)

# %%
data.describe()
# Out:
#             ODATEDW         TCODE           DOB           AGE       NUMCHLD  \
# count  95412.000000  95412.000000  95412.000000  71747.000000  12386.000000
# mean    9141.363256     54.223117   2723.602933     61.611649      1.527773
# std      343.454752    953.844476   2132.241295     16.664199      0.806861
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     48.000000      1.000000
# 50%     9201.000000      1.000000   2610.000000     62.000000      1.000000
# 75%     9501.000000      2.000000   4601.000000     75.000000      2.000000
# max     9701.000000  72002.000000   9710.000000     98.000000      7.000000
#
#              INCOME       WEALTH1           HIT       MBCRAFT      MBGARDEN  \
# count  74126.000000  50680.000000  95412.000000  42558.000000  42558.000000
# mean       3.886248      5.345699      3.321438      0.152075      0.059166
# ...

# %%
data=data.replace(' ' , np.nan)

# %%
NumCols=data.select_dtypes(np.number).columns
NumCols= list(set(NumCols))
len(NumCols)
# Out:
# 407

# %% [markdown]
# - Check for null values in the numerical columns.
#
# - Use appropriate EDA technique where ever necessary.

# %%
dataNum=data[NumCols]
dataNum
# Out:
#        EIC10  RDATE_5  CHIL1  RDATE_20  HC17  VIETVETS  AFC2  RAMNT_11  EIC15  \
# 0          5      NaN     31       NaN    33        34     0       NaN      1
# 1          4      NaN     33       NaN    99        55     0       NaN     11
# 2          3      NaN     35       NaN    22        29     0       NaN      3
# 3          3      NaN     45    9411.0    23        14     0      10.0      3
# 4          7      NaN     34       NaN    99         9     1       NaN      4
# ...      ...      ...    ...       ...   ...       ...   ...       ...    ...
# 95407      5      NaN     45       NaN    93        47    15       NaN      7
# 95408      6      NaN     33       NaN    69        43     0       NaN     13
# 95409      2      NaN     46       NaN    99        46     0       NaN      3
# 95410      7      NaN     38       NaN    99        35     0      18.0      9
# 95411      5      NaN     40       NaN    94        22     1     200.0      6
#
# ...

# %%
NullList=[]
for col in dataNum.columns:
    if dataNum[col].isna().sum()>0:
        NullList.append(col)
    else:
        continue
print (NullList)
# Out:
# ['RDATE_5', 'RDATE_20', 'RAMNT_11', 'PUBPHOTO', 'ADATE_17', 'ADATE_23', 'NUMCHLD', 'ADATE_4', 'ADATE_12', 'ADATE_24', 'PUBHLTH', 'PUBGARDN', 'MAGFAML', 'ADATE_21', 'RDATE_10', 'RDATE_15', 'RDATE_24', 'ADATE_18', 'RDATE_17', 'RDATE_16', 'NEXTDATE', 'MSA', 'RDATE_23', 'CLUSTER2', 'RDATE_6', 'ADI', 'MBCRAFT', 'RAMNT_9', 'RAMNT_7', 'MBGARDEN', 'ADATE_14', 'RDATE_19', 'ADATE_13', 'MBBOOKS', 'DMA', 'ADATE_9', 'RAMNT_20', 'ADATE_7', 'AGE', 'RDATE_14', 'MAGFEM', 'PUBNEWFN', 'RAMNT_3', 'RAMNT_8', 'ADATE_22', 'ADATE_6', 'RAMNT_13', 'RDATE_8', 'ADATE_3', 'PUBOPP', 'TIMELAG', 'RAMNT_5', 'WEALTH2', 'RDATE_12', 'ADATE_20', 'RAMNT_19', 'RAMNT_14', 'RAMNT_18', 'RAMNT_16', 'RAMNT_12', 'ADATE_15', 'RDATE_3', 'RAMNT_24', 'ADATE_10', 'RDATE_4', 'INCOME', 'RAMNT_17', 'MBCOLECT', 'RAMNT_4', 'MAGMALE', 'RDATE_21', 'RAMNT_23', 'ADATE_19', 'ADATE_8', 'RAMNT_21', 'ADATE_16', 'RAMNT_10', 'PUBDOITY', 'RDATE_7', 'RAMNT_22', 'RDATE_22', 'ADATE_5', 'RDATE_11', 'RDATE_9', 'RDATE_18', 'PUBCULIN', 'WEALTH1', 'RAMNT_6
# ...

# %%
dataNum[NullList].isna().sum() #91 of 407 columns from the numerical data do contain nulls
# Out:
# RDATE_5     95403
# RDATE_20    87524
# RAMNT_11    80672
# PUBPHOTO    52854
# ADATE_17    27650
#             ...
# WEALTH1     44732
# RAMNT_6     94636
# RAMNT_15    88150
# RDATE_13    83162
# ADATE_11    10422
# Length: 91, dtype: int64

# %%
nulls = pd.DataFrame(dataNum.isna().sum()*100/len(data), columns=['percentage'])
nulls.sort_values('percentage', ascending = False).head(91)
#checking for nulls in numerical data
# Out:
#           percentage
# RDATE_5    99.990567
# RAMNT_5    99.990567
# RDATE_3    99.746363
# RAMNT_3    99.746363
# RAMNT_4    99.705488
# ...              ...
# ADATE_3     2.043768
# CLUSTER2    0.138347
# MSA         0.138347
# DMA         0.138347
# ADI         0.138347
#
# [91 rows x 1 columns]

# %%
cols_to_drop=list(nulls[nulls['percentage'] >= 10].index)
cols_to_drop
data[cols_to_drop]
# Out:
#        RDATE_5  RDATE_20  RAMNT_11  PUBPHOTO  ADATE_17  ADATE_23  NUMCHLD  \
# 0          NaN       NaN       NaN       NaN    9502.0    9407.0      NaN
# 1          NaN       NaN       NaN       0.0       NaN       NaN      1.0
# 2          NaN       NaN       NaN       0.0       NaN    9407.0      NaN
# 3          NaN    9411.0      10.0       0.0    9502.0       NaN      NaN
# 4          NaN       NaN       NaN       0.0    9502.0    9407.0      1.0
# ...        ...       ...       ...       ...       ...       ...      ...
# 95407      NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 95408      NaN       NaN       NaN       0.0       NaN       NaN      1.0
# 95409      NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 95410      NaN       NaN      18.0       NaN    9502.0    9407.0      NaN
# 95411      NaN       NaN     200.0       0.0    9502.0    9407.0      NaN
#
#        ADATE_24  PUBHLTH  PUBGARDN  ...  ADATE_5  RDATE_11  RDATE_9  RDATE_18  \
# ...

# %%
data1=data.drop(columns=cols_to_drop, axis=1)
data1
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R MDMAUD_F  \
# ...

# %%
data1['GEOCODE2'].value_counts()
#I decide to drop the 187 rows without a letter
# Out:
# A    34484
# B    28505
# D    16580
# C    15524
#        187
# Name: GEOCODE2, dtype: int64

# %%
data1['GEOCODE2'].isna().sum() # those are differnt rows than those with nans
# Out:
# 132

# %%
data1['GEOCODE2']=data1['GEOCODE2'].replace(' ' , np.nan) #so I replace the empty rows and 
# drop the nan rows of that column

# %%
data1['GEOCODE2'].isna().sum()
# Out:
# 319

# %%
data1=data1.dropna(subset=['GEOCODE2'])

# %%
data1['GEOCODE2'].value_counts() #just to check if the empty entries are gone
# Out:
# A    34484
# B    28505
# D    16580
# C    15524
# Name: GEOCODE2, dtype: int64

# %%
data1['GEOCODE2'].isna().sum() # just to check if the nans are really gone...
# Out:
# 0

# %%
data1
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R MDMAUD_F  \
# ...

# %% [markdown]
# - Use appropriate methods to clean the columns `GEOCODE2`, `WEALTH1`, `ADI`, `DMA`,and `MSA`.

# %%
data[cols_to_drop]['WEALTH1'].isna().sum()/len(data)
it had 46% Nulls, so I had dropped this column before
# Out:
# 0.4688299165723389

# %%
data1['WEALTH1'].isna().sum()

# %%
data1['ADI']=data1['ADI'].replace(' ' , np.nan)

# %%
data1['ADI'].isna().sum()
# Out:
# 0

# %%
data['ADI'].isna().sum() #the nans have been allready gone through dealing with the 
#nan's of the other columns
# Out:
# 132

# %%
data1['GEOCODE2']=data1['GEOCODE2'].replace(' ' , np.nan)

# %%
data1['ADI'].value_counts().sort_index()
# Out:
# 0.0       656
# 3.0        29
# 9.0        68
# 11.0       25
# 13.0     7296
#          ...
# 621.0     118
# 625.0      63
# 627.0      28
# 645.0     257
# 651.0       1
# Name: ADI, Length: 204, dtype: int64
